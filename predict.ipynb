# %%
from keras.models import load_model
import numpy as np
# Out:
# 2023-05-26 19:07:26.580386: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-05-26 19:07:27.240412: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-05-26 19:07:27.241605: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-26 19:07:37.125089: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
model = load_model("/home/mwaniki-new/Documents/deep_learning/Cats_Dogs/src/Model/model.h5")
X_test_on_disk = np.load("/home/mwaniki-new/Documents/deep_learning/Cats_Dogs/X_test.npy", mmap_mode='r')
# Out:
# 2023-05-26 19:07:50.906739: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:266] failed call to cuInit: CUDA_ERROR_UNKNOWN: unknown error
# 2023-05-26 19:07:51.122023: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 25690112 exceeds 10% of free system memory.
# 2023-05-26 19:07:51.146047: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 25690112 exceeds 10% of free system memory.
# 2023-05-26 19:07:51.156346: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 25690112 exceeds 10% of free system memory.
# 2023-05-26 19:07:51.459476: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 25690112 exceeds 10% of free system memory.
# 2023-05-26 19:07:51.465573: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 25690112 exceeds 10% of free system memory.

# %%
test_pred = model.predict(X_test_on_disk)
# Out:
# Canceled future for execute_request message before replies were done
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
print(test_pred[2])
# Out:
# [0.48006043]

# %%
test_pred.shape
# Out:
# (12500, 1)

# %%
import pandas as pd

df = pd.read_csv("/home/mwaniki-new/Documents/sample_submission.csv")

df['label'] = test_pred

df.to_csv("/home/mwaniki-new/Documents/sample_submission.csv", index=False)

# %%
df.head(50)
# Out:
#     id     label
# 0    1  0.402454
# 1    2  0.976325
# 2    3  0.480060
# 3    4  0.257785
# 4    5  0.500462
# 5    6  0.024345
# 6    7  0.043985
# 7    8  0.058975
# 8    9  0.506230
# 9   10  0.087005
# 10  11  0.374522
# 11  12  0.106378
# 12  13  0.506230
# 13  14  0.047810
# 14  15  0.809775
# 15  16  0.470730
# 16  17  0.995621
# 17  18  0.678403
# 18  19  0.128117
# 19  20  0.022773
# 20  21  0.506230
# 21  22  0.056375
# 22  23  0.023507
# 23  24  0.079380
# 24  25  0.357459
# 25  26  0.567906
# 26  27  0.941862
# 27  28  0.236078
# 28  29  0.030475
# 29  30  0.281393
# 30  31  0.034529
# 31  32  0.150915
# 32  33  0.034511
# 33  34  0.230725
# 34  35  0.941295
# 35  36  0.015730
# 36  37  0.277465
# 37  38  0.193309
# 38  39  0.081029
# 39  40  0.067003
# 40  41  0.139391
# 41  42  0.100550
# 42  43  0.506230
# 43  44  0.023606
# 44  45  0.364709
# 45  46  0.463019
# 46  47  0.506230
# 47  48  0.163043
# 48  49  0.506230
# 49  50  0.265567

# %%
#df['label'] = df['label'].round()
#df.head(20)
# Out:
#     id  label
# 0    1    0.0
# 1    2    1.0
# 2    3    0.0
# 3    4    0.0
# 4    5    1.0
# 5    6    0.0
# 6    7    0.0
# 7    8    0.0
# 8    9    1.0
# 9   10    0.0
# 10  11    0.0
# 11  12    0.0
# 12  13    1.0
# 13  14    0.0
# 14  15    1.0
# 15  16    0.0
# 16  17    1.0
# 17  18    1.0
# 18  19    0.0
# 19  20    0.0

# %%
df.to_csv("/home/mwaniki-new/Documents/sample_submission.csv", index=False)
